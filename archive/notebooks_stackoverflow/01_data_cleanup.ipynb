# %%
# !rm -rf ../data/df_raw/*
# !gsutil -m cp -r gs://np-training-tmp/stackoverflow/posts_processed/*.parquet ../data/raw/

# %%
#!pip install plotly

# %%
#import plotly.express as px

# %%
from pyspark.sql import SparkSession
import re
import lxml.html
from pyspark.sql.types import StringType, ArrayType
import pyspark.sql.functions as F
import pandas as pd

# %%
spark = SparkSession\
.builder\
.appName('app')\
.config("spark.default.parallelism",200) \
.config("spark.sql.shuffle.partitions",200) \
.getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/10/23 16:16:42 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 22/10/23 16:16:42 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 22/10/23 16:16:42 INFO org.apache.spark.SparkEnv: Registering BlockManagerMasterHeartbeat
# 22/10/23 16:16:42 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator

# %%
posts_path = "gs://np-training-tmp/stackoverflow/output/posts__qn_with_top_answer/"
posts_link_path = "gs://np-training-tmp/stackoverflow/output/posts__links/"

# %%
df_posts = spark.read.parquet(posts_path)

# %%
df_posts.show(5)
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# +--------+----------------+--------------------+--------------------+--------------------+---------+-----------+------------+-----+--------------------+--------+------------------+
# |      Id|AcceptedAnswerId|               Title|        QuestionBody|                Tags|ViewCount|AnswerCount|CommentCount|Score|        CreationDate|AnswerId|AcceptedAnswerBody|
# +--------+----------------+--------------------+--------------------+--------------------+---------+-----------+------------+-----+--------------------+--------+------------------+
# |24460667|            null|Gnumake rules wit...|<p>I'm looking fo...|<makefile><gnu-ma...|      679|          2|           3|    0|2014-06-27 20:56:...|    null|              null|
# |70430813|            null|Multiple statuses...|<p>when i check t...|<formsflow.ai><fo...|       24|          1|           0|    1|2021-12-21 04:51:...|    null|              null|
# |71029804|            null|How to mock Amazo...|<p>I'm trying to ...|<java><unit-testi...|      199|          0|           0|    1|2022-02-08 07:08:...|    null|              null|
# |49506874|            null|Visual Studio cra...|<p>I have created...|<sql-server><visu...|      350|          0|           2|    0|2018-03-27 07:33:...|    null|              null|
# |71956620|            null|In FBX file, I ca...|<p>I am very new ...|<3d><direct3d><3d...|       37|          1|           0|    0|2022-04-21 14:57:...|    null|              null|
# +--------+----------------+--------------------+--------------------+--------------------+---------+-----------+------------+-----+--------------------+--------+------------------+
# only showing top 5 rows

# %%
df_posts_link = spark.read.parquet(posts_link_path)

# %%
df_posts_link.show(5)
# Out:
# +------------+--------+-----------+
# |component_id|      Id|OtherPostId|
# +------------+--------+-----------+
# |       11857|48483506|   40872114|
# |      111173|26220432|   13252603|
# |       41872|24063986|      32332|
# |      248533|31704180|    1803627|
# |       49609|53596207|   53524127|
# +------------+--------+-----------+
# only showing top 5 rows

# %%
regex = r"""
	<pre>.*?</pre>
	"""

def clean_text(snippet:str):
    
    if not snippet:
        return snippet
    snippet = re.sub(pattern=regex, repl = '[CODE]', string = snippet,  flags = re.IGNORECASE | re.DOTALL | re.MULTILINE | re.VERBOSE )
    
    snippet = str(lxml.html.fromstring(snippet).text_content())
    
    return snippet

def parse_tags(content:str):
    return re.findall(r'<(.+?)>',content)


udf_clean_text = F.udf(lambda x:clean_text(x),StringType() )
udf_parse_tags = F.udf(lambda x:parse_tags(x),ArrayType (StringType() ))

# %%
clean_text(f"""

<p>I was asked to create a singleton that will..</p>.

<pre><code>KDF </code></pre>

<p> test </p>

""")
# Out:
# 'I was asked to create a singleton that will...\n\n[CODE]\n\n test \n\n'

# %%
clean_text('')
# Out:
# ''

# %%
clean_text(None)

# %%
df_posts_processed = df_posts \
                        .withColumn("QuestionBody",udf_clean_text(F.col("QuestionBody"))) \
                        .withColumn("AcceptedAnswerBody",udf_clean_text(F.col("AcceptedAnswerBody"))) \
                        .withColumn("Tags",udf_parse_tags(F.col("Tags"))) \
                        .cache()

# %%
df_posts_processed.where(F.col("AcceptedAnswerBody").isNotNull()).show(5)
# Out:
# [Stage 4:>                                                          (0 + 1) / 1]
# +--------+----------------+--------------------+--------------------+--------------------+---------+-----------+------------+-----+--------------------+--------+--------------------+
# |      Id|AcceptedAnswerId|               Title|        QuestionBody|                Tags|ViewCount|AnswerCount|CommentCount|Score|        CreationDate|AnswerId|  AcceptedAnswerBody|
# +--------+----------------+--------------------+--------------------+--------------------+---------+-----------+------------+-----+--------------------+--------+--------------------+
# | 3503488|         3608698|Why is Visual Stu...|this could be see...|[visual-studio-20...|      216|          1|           3|    1|2010-08-17 14:27:...| 3608698|The issue that re...|
# |64419701|        64419983|Confused by R cod...|Chapt. 6.2 of Hyn...|                 [r]|       51|          1|           3|    0|2020-10-19 00:34:...|64419983|It's a MA of orde...|
# |18900705|        18900858|Javascript case s...|I have a problem ...|[javascript, vari...|     7916|          5|           0|    1|2013-09-19 16:55:...|18900858|Check out this an...|
# |45912123|        45912228|WinForms Applicat...|I have made a Win...|[c#, winforms, de...|     1168|          1|           3|    1|2017-08-28 05:14:...|45912228|Make sure you rig...|
# |11528647|        11530185|Is there a way to...|Let's say I've go...|  [svn, tortoisesvn]|     1138|          3|           0|    2|2012-07-17 18:30:...|11530185|command line:
#
#
#  ...|
# +--------+----------------+--------------------+--------------------+--------------------+---------+-----------+------------+-----+--------------------+--------+--------------------+
# only showing top 5 rows

# %%
pdf_top_tags = df_posts_processed\
.where(F.col("AcceptedAnswerBody").isNotNull()) \
.select(F.explode("Tags").alias('tag')) \
.groupby(['tag']) \
.count() \
.toPandas() \
.sort_values(['count'], ascending=False)

# %%
pdf_top_tags.head(30)
# Out:
#                  tag    count
# 24158     javascript  1264162
# 56543         python  1014931
# 49960           java   925828
# 12483             c#   865432
# 52019            php   748739
# 3332         android   617115
# 15506           html   610678
# 23882         jquery   594328
# 34774            c++   441122
# 24495            css   424461
# 25753            sql   370138
# 19361          mysql   345718
# 56224            ios   332399
# 50849              r   255448
# 24816         arrays   243312
# 36530              c   216423
# 15505        asp.net   195204
# 59046  ruby-on-rails   190936
# 53796           .net   190596
# 12199        node.js   190505
# 18532           json   183820
# 28206     sql-server   176654
# 29921          regex   175801
# 39797    objective-c   173210
# 46108        reactjs   168263
# 54981     python-3.x   157417
# 44612          swift   156751
# 19104         pandas   149672
# 53798         django   146175
# 19106           ruby   136671

# %%
pd.set_option("max_rows", None)

# %%
pdf_top_tags.head(500)
# Out:
#                               tag    count
# 24158                  javascript  1264162
# 56543                      python  1014931
# 49960                        java   925828
# 12483                          c#   865432
# 52019                         php   748739
# 3332                      android   617115
# 15506                        html   610678
# 23882                      jquery   594328
# 34774                         c++   441122
# 24495                         css   424461
# 25753                         sql   370138
# 19361                       mysql   345718
# 56224                         ios   332399
# 50849                           r   255448
# 24816                      arrays   243312
# 36530                           c   216423
# 15505                     asp.net   195204
# 59046               ruby-on-rails   190936
# 53796                        .net   190596
# 12199                     node.js   190505
# 18532                        json   183820
# 28206                  sql-server   176654
# 29921                       regex   175801
# 39797                 objective-c   173210
# 46108                     reactjs   168263
# 54981                  python-3.x   157417
# 44612                       swift   156751
# 19104                      pandas   149672
# 53798                      django   146175
# 19106                        ruby   136671
# 2128                       iphone   132687
# 57463                   angularjs   131008
# 16415                       excel   125252
# 6002                      angular   122459
# 27585                         xml   116972
# 26382                      string   113450
# 45238                 asp.net-mvc   108937
# 22385                        ajax   108446
# 44314                       linux   107701
# 54982                         vba    98570
# 36531                         wpf    97018
# 17304                    database    95474
# 26384                  typescript    91684
# 34175                     laravel    89512
# 24820                        bash    89435
# 14899                      spring    86112
# 38279                        list    83021
# 5719                   postgresql    80600
# 3006                        xcode    78493
# 16122                     mongodb    76334
# 48159                   dataframe    76190
# 50235                         git    75938
# 59353                     windows    74647
# 12486              multithreading    73560
# 35041                   wordpress    73439
# 59354                      oracle    72802
# 14312                      vb.net    72269
# 4543                    algorithm    65077
# 26990                       scala    65004
# 33900                    function    60334
# 17305                       numpy    60240
# 24159                     eclipse    58236
# 16117                        linq    57959
# 18235                       forms    57768
# 22995           twitter-bootstrap    55709
# 6927                     firebase    55315
# 6617                     winforms    55172
# 6925                   powershell    55094
# 3005                        azure    55080
# 24491         amazon-web-services    54711
# 35043               visual-studio    53399
# 54702                       image    53399
# 19691                       macos    52578
# 47550                 performance    51906
# 23885                       loops    51791
# 3008                      flutter    51546
# 54983                  python-2.7    50598
# 55896                      matlab    50365
# 36850                       shell    49679
# 44012                      sqlite    49224
# 19367            entity-framework    48763
# 23001                        tsql    46858
# 22990                 spring-boot    45799
# 40116                       class    45534
# 19690                      docker    45472
# 57778                  dictionary    45065
# 59355                       swing    44485
# 620                            qt    44235
# 33599                        date    43730
# 31715                     sorting    43665
# 36852                         csv    43439
# 51148                      vue.js    43199
# 15807                        perl    42884
# 53799                unit-testing    42456
# 13134                         api    42148
# 25131                react-native    41526
# 55259                    datetime    41477
# 34775                   hibernate    41011
# 28490                      apache    40549
# 32327                        file    40288
# 32328                        rest    39895
# 18237                    for-loop    39751
# 29646                    selenium    39401
# 41614                     express    38381
# 6928                          oop    37516
# 14904                      object    37272
# 31131             ruby-on-rails-3    36933
# 13437                       c++11    36871
# 44909                        xaml    36064
# 23004                          go    35821
# 35346                     symfony    35789
# 33898                 uitableview    35710
# 48459                       maven    35623
# 57783                    facebook    35323
# 43703                  validation    35322
# 38007                   .htaccess    34944
# 29336                      kotlin    34921
# 32919                  matplotlib    34768
# 47839                if-statement    34724
# 29643                    pointers    34631
# 6924                      haskell    34519
# 2130                         dart    33745
# 36853                 codeigniter    33743
# 16118             sql-server-2008    33579
# 5414                    templates    33510
# 57467                asp.net-core    32969
# 46414                apache-spark    32593
# 22994              android-studio    32498
# 37164                     parsing    32402
# 14599                 google-maps    31273
# 49065                    generics    31069
# 19362                        http    30867
# 10115                      delphi    30840
# 21501                   variables    30738
# 54380                     sockets    29679
# 34484              android-layout    29640
# 16736                     ggplot2    29206
# 39493               google-chrome    28663
# 22387              user-interface    28618
# 13436                  tensorflow    28618
# 21827                web-services    28229
# 56547                  batch-file    28220
# 56545                   ms-access    28072
# 10116                    security    27954
# 24815          visual-studio-2010    27641
# 54091                     unity3d    27401
# 26722                      opencv    27377
# 25130                    listview    26798
# 2134                         unix    26369
# 52024                   recursion    26347
# 36854                  spring-mvc    26270
# 30823                asynchronous    26046
# 25461                         wcf    25958
# 10405               asp.net-mvc-3    25893
# 58739                        math    25536
# 35969                 inheritance    25478
# 45536                        join    25237
# 8375                        cocoa    24790
# 28491                       email    24782
# 11874                      ubuntu    24724
# 46989           google-app-engine    24519
# 41308                   debugging    24484
# 20320                   jquery-ui    24280
# 34178                        xslt    24279
# 38594                         jsp    24094
# 7214               actionscript-3    24075
# 32923                      github    24046
# 36243                      select    23943
# 34174               elasticsearch    23516
# 36537                 cocoa-touch    23510
# 12485                     cordova    23498
# 18813                       xpath    23220
# 24508                         dom    23165
# 15511                     tkinter    23047
# 43706              authentication    22877
# 40117                      matrix    22874
# 24166                      winapi    22667
# 26387               asp.net-mvc-4    22632
# 57777                   exception    22388
# 4829                google-sheets    22299
# 39194                web-scraping    22260
# 40437                     xamarin    22230
# 21826                         awk    22229
# 17937                       dplyr    21913
# 19689                         jpa    21909
# 36242                       flask    21892
# 26723                     testing    21759
# 12831                   animation    21699
# 12203      multidimensional-array    21581
# 42813          google-apps-script    21577
# 41319                         url    21554
# 8099             machine-learning    21499
# 15508                      opengl    21443
# 56550                         gcc    21248
# 54377                      button    21048
# 42537                      vector    20998
# 4266                django-models    20951
# 43408           android-fragments    20949
# 17936                      events    20932
# 6009                        d3.js    20919
# 56552                    assembly    20906
# 32001                         svg    20557
# 1520                      session    20451
# 11289             ruby-on-rails-4    20376
# 7518                     mongoose    20298
# 41309                      random    20088
# 31718                        plot    20025
# 54707                optimization    19722
# 26392                      gradle    19704
# 49071                         web    19448
# 51152           stored-procedures    19409
# 914                    kubernetes    19357
# 22997                         ssl    19255
# 23313                   arraylist    19138
# 1814             image-processing    19128
# 51734                        post    19061
# 54704                        ipad    19041
# 3338                       lambda    18941
# 47552                         sed    18940
# 45528           internet-explorer    18936
# 34478                         pdf    18923
# 58087                       flash    18810
# 30826                       razor    18782
# 13439                     logging    18760
# 26400               intellij-idea    18756
# 43704                      search    18718
# 35975                       nginx    18712
# 29935          selenium-webdriver    18669
# 55262                   laravel-5    18586
# 11593                    redirect    18499
# 2411                         curl    18452
# 19996                      canvas    18366
# 20324                 mod-rewrite    18260
# 35040             design-patterns    18228
# 34476                         vim    18223
# 12204                    indexing    18217
# 12844                     firefox    18152
# 3968                       struct    18099
# 42814                   amazon-s3    18051
# 5119                         rust    17902
# 29922                      heroku    17796
# 12832               serialization    17773
# 45240                         jsf    17683
# 9551   firebase-realtime-database    17647
# 21513                      tomcat    17624
# 15809             data-structures    17605
# 29929             asp.net-web-api    17575
# 14003                   .net-core    17553
# 56230                      memory    17544
# 17943               beautifulsoup    17539
# 6                           input    17497
# 32335                activerecord    17447
# 9831                       javafx    17438
# 37457                     cakephp    17330
# 13741                ecmascript-6    17284
# 22693                     jenkins    17234
# 55898                     replace    17218
# 52314                 silverlight    17132
# 38596                     methods    17064
# 52922                  encryption    17016
# 32325      google-cloud-firestore    17005
# 19363                       types    16908
# 54090                      hadoop    16902
# 12492                        mvvm    16821
# 26718                     caching    16776
# 12502       model-view-controller    16741
# 53810                   core-data    16637
# 38597                    checkbox    16636
# 50544                        text    16623
# 13742             ionic-framework    16610
# 12495                         npm    16463
# 1812                      magento    16280
# 46988                        time    16255
# 46411                  networking    16203
# 44016                  visual-c++    16193
# 10703                    group-by    16080
# 1221                        boost    15989
# 29023                    servlets    15960
# 4545            memory-management    15911
# 15211                  reflection    15713
# 11891                      filter    15701
# 28207                         iis    15679
# 41610                      groovy    15665
# 40121                     foreach    15648
# 20606       google-cloud-platform    15481
# 53503                      grails    15383
# 23312                       keras    15348
# 8105                        redux    15333
# 44910          visual-studio-code    15242
# 50850                  jakarta-ee    15190
# 41022                         svn    15124
# 39499                 collections    15010
# 49064              android-intent    14912
# 35044               xamarin.forms    14873
# 56867                        jdbc    14802
# 54388                      layout    14771
# 53797                      meteor    14771
# 36244            android-activity    14630
# 19364                       split    14609
# 42817                     cookies    14557
# 43400                      c#-4.0    14489
# 52020                        hash    14471
# 33258                       audio    14439
# 24825               excel-formula    14408
# 57781                       plsql    14371
# 50240                     unicode    14344
# 18818                data-binding    14271
# 32607                     pyspark    14183
# 59673                     dynamic    14065
# 19991                 apache-flex    14058
# 2138              database-design    14051
# 32002          facebook-graph-api    14036
# 8102                   amazon-ec2    14026
# 18242        dependency-injection    14004
# 9834                      webpack    13962
# 23586                 bootstrap-4    13860
# 9837                   while-loop    13847
# 22101                      syntax    13816
# 3335                       java-8    13630
# 26720                       enums    13597
# 41019                       extjs    13594
# 627                      gridview    13592
# 19704                    ember.js    13567
# 9558                     eloquent    13546
# 58753                 async-await    13478
# 19686           google-maps-api-3    13268
# 46987                azure-devops    13259
# 15209                    makefile    13252
# 33902                      mysqli    13172
# 21832                 constructor    13170
# 49074                 knockout.js    13143
# 19693                       graph    13121
# 49389                       shiny    13111
# 37456                         pdo    13065
# 1532                   html-table    13053
# 23576                command-line    13031
# 51731                         cmd    13000
# 44611                     swiftui    12983
# 15512                       count    12980
# 51733                       merge    12975
# 29943                     file-io    12901
# 9842       functional-programming    12803
# 31133       django-rest-framework    12788
# 57465                      vuejs2    12787
# 41020             sql-server-2005    12773
# 27301                  highcharts    12761
# 59357                installation    12744
# 57167                         ssh    12719
# 13138                     casting    12696
# 20327              error-handling    12616
# 4553                        junit    12580
# 3976                      promise    12578
# 37732                       video    12511
# 21209                 backbone.js    12509
# 0                          iframe    12491
# 629                        charts    12455
# 54980                 file-upload    12435
# 24496                     clojure    12384
# 29928             windows-phone-7    12312
# 44014                 concurrency    12284
# 2421               zend-framework    12271
# 56868                    encoding    12111
# 25466                          f#    12063
# 5116                 scikit-learn    12053
# 26100                 woocommerce    11980
# 17620               jquery-mobile    11970
# 46698                   interface    11928
# 27591                  sharepoint    11873
# 14007                      mobile    11856
# 49384         twitter-bootstrap-3    11853
# 11589                         gwt    11831
# 41313                         tfs    11825
# 20907                        sass    11770
# 54703                         dll    11755
# 11592        android-recyclerview    11696
# 335                        import    11679
# 38601                  parameters    11619
# 19698                  nhibernate    11610
# 1816               drop-down-menu    11573
# 13443                     browser    11516
# 18601          visual-studio-2012    11490
# 10702                      colors    11468
# 6624                      twitter    11292
# 24817                       utf-8    11273
# 36540                       neo4j    11267
# 20903                django-views    11186
# 14909                        soap    11070
# 45835                     flexbox    11069
# 35971                         uwp    11056
# 59668             spring-security    11052
# 5                            rxjs    11012
# 49067                    netbeans    11007
# 26991                         lua    10979
# 26381          reporting-services    10969
# 27915                        view    10963
# 6933                        emacs    10915
# 23306                 react-hooks    10874
# 13737                    terminal    10861
# 44613                  properties    10860
# 19366             google-bigquery    10853
# 5724                       uiview    10852
# 10975            web-applications    10841
# 1523      google-chrome-extension    10841
# 24494                       scope    10813
# 22386                    graphics    10813
# 12834                     plugins    10786
# 5412                   deployment    10754
# 54711                       cmake    10741
# 44614                   datatable    10660
# 29343                         stl    10555
# 5413                        rspec    10546
# 20905                        grep    10433
# 29650                      module    10335
# 12499                       timer    10307
# 38878          visual-studio-2008    10304
# 24507                 linked-list    10285
# 41615             version-control    10270
# 32609                   reference    10247
# 8107                          orm    10247
# 27588                datagridview    10206
# 17942                  aws-lambda    10184
# 24505                 linq-to-sql    10175
# 45837                     service    10145
# 56544              docker-compose    10129
# 48460                apache-kafka    10125
# 41612            apache-spark-sql    10088
# 18231                         tcp    10034
# 41021                     binding    10033
# 12201                     ansible    10022
# 25133             compiler-errors     9989
# 27299            django-templates     9976
# 9843                        scipy     9963
# 34776                      drupal     9957
# 57466                   directory     9878
# 17022         parallel-processing     9871
# 24818                   oracle11g     9830
# 41960                django-forms     9798
# 48470                    printing     9785
# 17012                       model     9773
# 41625                   websocket     9768
# 36536                       redis     9756
# 59369                       https     9744
# 38014                      scroll     9738
# 11274                          io     9736
# 43107                      static     9728
# 12829                  sqlalchemy     9723
# 6936                         pyqt     9686
# 11278         angularjs-directive     9639
# 40734                       build     9633
# 59672                    callback     9621
# 39803                   scripting     9586
# 55901                      swift3     9546
# 40128                       fonts     9543
# 23011                    combobox     9536
# 2151                  react-redux     9478
# 39495                    triggers     9470
# 3646                       pygame     9389
# 20319                        path     9387
# 29645                      routes     9385
# 16735                memory-leaks     9355
# 57785                        null     9354
# 57799               css-selectors     9350
# 45529                      ffmpeg     9340
# 48757             sql-server-2012     9336
# 3334             uiviewcontroller     9255
# 30514               playframework     9247
# 45535                    vbscript     9245
# 22100              floating-point     9211
# 18816                    iterator     9209
# 12837               deep-learning     9202
# 6318              windows-phone-8     9073
# 27300               configuration     9023
# 9839                    hyperlink     8983
# 34486                    three.js     8921
# 37730          visual-studio-2013     8912
# 13132                         sum     8905
# 7229                      ms-word     8901
# 6627                   data.table     8885
# 29031                         yii     8868
# 22999          exception-handling     8848
# 10118              parse-platform     8827
# 37161               mongodb-query     8791
# 23310                doctrine-orm     8785
# 7797                          x86     8774
# 6618                      process     8742
# 42539                architecture     8729
# 19107                        cuda     8728
# 34790                  datatables     8699
# 3651                        jsf-2     8690
# 8680                   controller     8665
# 26994          visual-studio-2015     8662
# 57784                      nested     8622
# 1824              python-requests     8586
# 46990                     hashmap     8558
# 46114                        solr     8551
# 47555                         get     8510
# 21210                        tree     8446
# 11279                    datagrid     8443
# 34786                   laravel-4     8439
# 14002                       login     8435

# %%
df_posts_link
# Out:
# DataFrame[component_id: bigint, Id: bigint, OtherPostId: bigint]

# %%
pdf_top_tags_links = df_posts_link \
.join(df_posts_processed, df_posts_link.Id == df_posts_processed.Id ) \
.select(F.explode("Tags").alias('tag')) \
.groupby(['tag']) \
.count() \
.toPandas() \
.sort_values(['count'], ascending=False)

# %%
pdf_top_tags_links.head(20)
# Out:
#               tag   count
# 10257  javascript  101869
# 24191      python   99128
# 21340        java   93097
# 22264         php   65189
# 5279           c#   55303
# 6580         html   44764
# 14785         c++   43231
# 1409      android   32606
# 10389         css   32405
# 10136      jquery   28289
# 21739           r   25849
# 10527      arrays   25633
# 8223        mysql   24396
# 15561           c   23221
# 12727       regex   18007
# 23535  python-3.x   17751
# 10933         sql   16984
# 11202      string   14722
# 24069         ios   14540
# 8104       pandas   13163

# %%
tag_subset = [   'python','python-3.x','python-2.7','pandas'
                ,'pyspark','machine-learning','deep-learning'
                ,'scikit-learn' ,'tensorflow' ,'dataframe','r'
             ]

tag_subset_lit = F.array([F.lit(i) for i in tag_subset])

# %%
pdf_top_tags [ pdf_top_tags['tag'].isin(tag_subset) ]
# Out:
#                     tag    count
# 56543            python  1014931
# 50849                 r   255448
# 54981        python-3.x   157417
# 19104            pandas   149672
# 48159         dataframe    76190
# 54983        python-2.7    50598
# 13436        tensorflow    28618
# 8099   machine-learning    21499
# 32607           pyspark    14183
# 5116       scikit-learn    12053
# 12837     deep-learning     9202

# %%
#df_posts_processed_metada

# %%
df_posts_final = df_posts_processed \
.where ( 
 F.size(F.array_intersect(F.col("Tags"), tag_subset_lit ))    > 0
)

# %%
df_posts_final.show(5)
# Out:
# +--------+----------------+--------------------+--------------------+--------------------+---------+-----------+------------+-----+--------------------+--------+------------------+
# |      Id|AcceptedAnswerId|               Title|        QuestionBody|                Tags|ViewCount|AnswerCount|CommentCount|Score|        CreationDate|AnswerId|AcceptedAnswerBody|
# +--------+----------------+--------------------+--------------------+--------------------+---------+-----------+------------+-----+--------------------+--------+------------------+
# |33760194|            null|Python How to bur...|I'm writing the p...|[python, event-ha...|      491|          0|           2|    0|2015-11-17 15:02:...|    null|              null|
# |15020895|            null|Python int-byte e...|i am currently st...|[python, data-str...|      155|          0|           3|    1|2013-02-22 09:33:...|    null|              null|
# |47234657|            null|converting word i...|def translate(str...|[python, python-3.x]|       48|          2|           1|   -1|2017-11-11 05:23:...|    null|              null|
# |37310210|            null|Camera Calibratio...|I am working on a...|[python, python-2...|     8164|          2|           3|    3|2016-05-18 21:14:...|    null|              null|
# |70675292|            null|Python Same Perio...|I have following ...|[python, pandas, ...|       70|          1|           0|    0|2022-01-12 01:19:...|    null|              null|
# +--------+----------------+--------------------+--------------------+--------------------+---------+-----------+------------+-----+--------------------+--------+------------------+
# only showing top 5 rows

# %%
df_posts_final \
.toPandas() \
.to_parquet("gs://np-training-tmp/stackoverflow/final/posts.parquet", index=False)

# %%
df_posts_related =  df_posts_link \
.join(df_posts_processed.alias("A"), df_posts_link.Id == F.col("A.Id") ) \
.join(df_posts_processed.alias("B"), df_posts_link.OtherPostId == F.col("B.Id")) \
.selectExpr("component_id", "B.Id as PostId", "B.title as PostTitle", "A.title as RelatedPostTitle", "A.Id as RelatedPostId" , "B.Tags")  \
.where ( 
 F.size(F.array_intersect(F.col("Tags"), tag_subset_lit ))    > 0
)

# %%
df_posts_related
# Out:
# DataFrame[component_id: bigint, PostId: bigint, PostTitle: string, RelatedPostTitle: string, RelatedPostId: bigint, Tags: array<string>]

# %%
df_posts_related.printSchema()
# Out:
# root
#  |-- component_id: long (nullable = true)
#  |-- PostId: long (nullable = true)
#  |-- PostTitle: string (nullable = true)
#  |-- RelatedPostTitle: string (nullable = true)
#  |-- RelatedPostId: long (nullable = true)
#  |-- Tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
df_posts_related.show(5)
# Out:
# [Stage 16:====================================================> (205 + 5) / 210]
# +------------+-------+--------------------+--------------------+-------------+--------------------+
# |component_id| PostId|           PostTitle|    RelatedPostTitle|RelatedPostId|                Tags|
# +------------+-------+--------------------+--------------------+-------------+--------------------+
# |      350052| 116139|How can I search ...|Open and read eac...|     37130140|[python, ms-word,...|
# |      170688| 447117|Django: Increment...|Count number of V...|     46152452|[python, database...|
# |      262475| 472575|select single ite...|Python equivalent...|     46886903|[python, iterator...|
# |       50426|1444961|Is there a good P...|Generating tokens...|      6843021|       [c++, python]|
# |      227083|1506901|Cleanest and most...|Get tommorow's da...|     69364070|[python, datetime...|
# +------------+-------+--------------------+--------------------+-------------+--------------------+
# only showing top 5 rows

# %%
def flatten_related_post(records:pd.DataFrame):
    #print (type(records))
    
    res = { 'PostId' : records.iloc[0]['PostId'] 
           , 'PostTitle' : records.iloc[0]['PostTitle']
           , 'RelatedPostIds' : [records.iloc[0]['PostId']] + list(records['RelatedPostId'])
           , 'RelatedPostTitles' : [records.iloc[0]['PostTitle']] + list(records['RelatedPostTitle'])
           , 'num_candidates':len(records) + 1 ,
          }
    return pd.Series(res)

# %%
pdf_related_posts = df_posts_related \
.toPandas() \
.groupby(['component_id'], as_index=False).apply(flatten_related_post) \
.drop(columns=['component_id'])

# %%
pdf_related_posts.head(5)
# Out:
#      PostId                                          PostTitle  \
# 0  57348742    How do I simulate a Scrollbar in tkInter Canvas
# 1   3494593  Shading a kernel density plot between two points.
# 2  37949409                       Dictionary in a numpy array?
# 3  51519086  How to remove tkinter - - - - line's when crea...
# 4  63107594  How to deal with multi-level column names down...
#
#                                       RelatedPostIds  \
# 0                               [57348742, 68340045]
# 1  [3494593, 14863744, 14094644, 16504452, 488531...
# 2                     [37949409, 47689224, 61517741]
# 3                               [51519086, 55088055]
# 4  [63107594, 63107603, 62966295, 68674235, 63124...
#
#                                    RelatedPostTitles  num_candidates
# 0  [How do I simulate a Scrollbar in tkInter Canv...               2
# 1  [Shading a kernel density plot between two poi...              16
# 2  [Dictionary in a numpy array?, How to access t...               3
# 3  [How to remove tkinter - - - - line's when cre...               2
# 4  [How to deal with multi-level column names dow...               6

# %%
pdf_related_posts['num_candidates'].value_counts()
# Out:
# 2      23992
# 3       4641
# 4       1770
# 5        887
# 6        538
# 7        311
# 8        201
# 9        160
# 10       135
# 11        78
# 12        60
# 14        60
# 13        57
# 16        44
# 17        39
# 15        34
# 20        28
# 19        18
# 18        16
# 24        14
# 22        14
# 23        13
# 30        13
# 21        11
# 26        10
# 25        10
# 29         9
# 27         6
# 33         6
# 34         6
# 31         5
# 28         5
# 43         4
# 40         3
# 36         3
# 38         3
# 41         3
# 49         2
# 47         2
# 32         2
# 76         2
# 39         2
# 61         2
# 87         1
# 54         1
# 57         1
# 153        1
# 58         1
# 60         1
# 85         1
# 53         1
# 77         1
# 84         1
# 52         1
# 128        1
# 66         1
# 98         1
# 35         1
# 99         1
# 37         1
# 70         1
# 103        1
# 72         1
# 42         1
# 106        1
# 939        1
# 44         1
# 64         1
# 46         1
# 112        1
# 50         1
# 63         1
# Name: num_candidates, dtype: int64

# %%
pdf_related_posts \
.to_parquet("gs://np-training-tmp/stackoverflow/final/related_posts.parquet", index=False)

# %%
# fig = px.histogram(pdf_related_posts, x="num_candidates")
# fig.show()

# %%
pdf_related_posts \
.to_parquet("gs://np-training-tmp/stackoverflow/final/related_posts.parquet", index=False)
