# %%
import concurrent.futures
import glob
from haystack.document_stores import FAISSDocumentStore
from haystack.nodes import EmbeddingRetriever
import multiprocessing
from tqdm.contrib.concurrent import process_map
import pandas
import haystack

# %%
files = glob.glob("../data/df_processed/*.parquet")
files
# Out:
# ['../data/df_processed/part-0004.snappy.parquet',
#  '../data/df_processed/part-0011.snappy.parquet',
#  '../data/df_processed/part-0015.snappy.parquet',
#  '../data/df_processed/part-0021.snappy.parquet',
#  '../data/df_processed/part-0024.snappy.parquet',
#  '../data/df_processed/part-0001.snappy.parquet',
#  '../data/df_processed/part-0012.snappy.parquet',
#  '../data/df_processed/part-0010.snappy.parquet',
#  '../data/df_processed/part-0018.snappy.parquet',
#  '../data/df_processed/part-0008.snappy.parquet',
#  '../data/df_processed/part-0028.snappy.parquet',
#  '../data/df_processed/part-0009.snappy.parquet',
#  '../data/df_processed/part-0006.snappy.parquet',
#  '../data/df_processed/part-0022.snappy.parquet',
#  '../data/df_processed/part-0016.snappy.parquet',
#  '../data/df_processed/part-0003.snappy.parquet',
#  '../data/df_processed/part-0013.snappy.parquet',
#  '../data/df_processed/part-0027.snappy.parquet',
#  '../data/df_processed/part-0014.snappy.parquet',
#  '../data/df_processed/part-0025.snappy.parquet',
#  '../data/df_processed/part-0029.snappy.parquet',
#  '../data/df_processed/part-0000.snappy.parquet',
#  '../data/df_processed/part-0007.snappy.parquet',
#  '../data/df_processed/part-0031.snappy.parquet',
#  '../data/df_processed/part-0005.snappy.parquet',
#  '../data/df_processed/part-0017.snappy.parquet',
#  '../data/df_processed/part-0019.snappy.parquet',
#  '../data/df_processed/part-0023.snappy.parquet',
#  '../data/df_processed/part-0002.snappy.parquet',
#  '../data/df_processed/part-0030.snappy.parquet',
#  '../data/df_processed/part-0026.snappy.parquet',
#  '../data/df_processed/part-0020.snappy.parquet']

# %%
def convert_to_document_dict(row):
    d = row.to_dict()
    #d['content']=d['Title'] + "\n" + d['Body']
    
    d['content']=d['Title']
    d['id']= d['Id']
    d['Tags'] = d['Tags']
    del d['Id']
    del d['Body']
    del d['AnswerBody']
    d_doc = haystack.schema.Document.from_dict(d)
    
    return d_doc


def get_document_store():
    
    document_store = FAISSDocumentStore(faiss_index_factory_str="Flat",return_embedding=True)
    return document_store


def transform_file_batch(path: str) -> int:
    
    df = pandas.read_parquet(path)
    
    docs = df.apply(convert_to_document_dict, axis=1)
    
        
    return docs

# %%
document_store_faiss = get_document_store()

# %%
#FAISS Retriever initialization
retriever_faiss = EmbeddingRetriever(document_store_faiss
    ,embedding_model='distilroberta-base-msmarco-v2'
    , model_format='sentence_transformers')
# Out:
# WARNING:haystack.nodes.retriever._embedding_encoder:You are using a Sentence Transformer with the dot_product function. We recommend using cosine instead. This can be set when initializing the DocumentStore

# %%
# Delete existing documents in documents store
document_store_faiss.delete_documents()

# %%
cores = multiprocessing.cpu_count()-2

# %%
# Write documents to document store

# max_workers=10
with concurrent.futures.ProcessPoolExecutor(max_workers = cores) as executor:
    for file_path, docs in zip(files, executor.map(transform_file_batch, files)):
        
        document_store_faiss.write_documents(docs)
        
        print(f"path:{file_path}; records:{len(docs)}")
# Out:
# Writing Documents:   0%|          | 0/362133 [00:00<?, ?it/s]
# ERROR:haystack.document_stores.sql:Document 36308472 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 33723298 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 35772072 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 30680938 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 7603142 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 8001079 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 61414112 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 41831719 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 14116846 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 32897947 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 43379692 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 39244928 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 22223954 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 8174561 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 31692498 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 18280074 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 39709984 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 68051240 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 67782980 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 50230775 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 22735915 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 24991273 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 794735 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 67762588 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 51302372 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 68524520 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 30108510 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 64314391 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 3781148 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 10538917 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 29141666 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 52215917 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 53947560 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 5136268 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 34358256 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 37244175 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 6058158 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 22566443 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 17530462 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 20473308 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 47184406 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 11180776 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 4141305 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 22072102 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 36250423 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 47617331 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 53427137 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 16096338 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 71625296 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 60928121 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 56561866 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 16008820 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 11623773 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 69036911 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 57540205 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 22784978 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 42006253 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 59421634 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 54943584 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 37324513 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 47141354 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 16610774 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 1220166 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 4960407 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 42423569 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 22669367 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 18365923 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 11255389 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 14530862 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 59158587 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 16438666 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 55924890 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 61747772 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 61839084 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 52369111 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 6222520 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 42827169 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 31343890 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 18638159 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 23637828 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 21997725 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 7048843 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 33223139 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 16501597 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 60551296 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 65832284 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 13792419 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 21529657 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 13674696 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 28381342 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 32952865 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 41792 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 62789310 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 19494069 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 6830797 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 71942019 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 26824886 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 971076 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 59869117 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 57696536 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 44338698 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 47039384 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 32580129 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 3958463 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 20224026 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 25223775 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 45167518 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 57268200 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 10997946 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 17000387 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 31755192 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 7205734 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 39839458 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 3701960 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 68580137 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 29651243 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 12016790 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 12838715 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 29351153 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 68412545 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 19490347 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 41630279 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 22677082 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 62081680 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 43121122 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 48726527 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 7664826 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 679595 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 35922415 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 54383169 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 10984216 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 8410210 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 14823525 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 69344284 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 62391346 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 23237267 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 37076181 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 7261881 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType
# ERROR:haystack.document_stores.sql:Document 36555343 - Discarded metadata 'CreationDate', since it has invalid type: Timestamp.
# SQLDocumentStore can accept and cast to string only the following types: str, int, float, bool, bytes, bytearray, NoneType

# %%
# !ls

# %%
# Add documents embeddings to index
document_store_faiss.update_embeddings(retriever=retriever)
