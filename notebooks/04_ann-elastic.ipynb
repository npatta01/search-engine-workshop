# %% [markdown]
# # Neural Information Retrieval Using Nearest Neighbor
#
#
# Neural retrieval for information retrieval (IR) use embeddings to search for similar items in an search space build using search corpus data.
#
# <br/>
# We will FAISS library from Facebook for our hands-on presentation. But one could look <a href="http://ann-benchmarks.com/">here</a> to find other solutions and benchmark data.
#
#
# We will look at `performance` and `recall@1`

# %% [markdown]
# ## Load the libraries

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import faiss
import datasets
from elasticsearch import Elasticsearch
from elasticsearch.helpers import streaming_bulk
import tqdm
import rich
from sentence_transformers import SentenceTransformer
from IPython.display import Image, JSON
from IPython.core.display import HTML
import requests
import ipyplot
import time

# %% [markdown]
# ## Load the embeddings of the image corpus

# %%
dset = datasets.load_from_disk("../data/processed_embeddings")
## these embeddings will be used to create the search space.
corpus = dset['embeddings']


corpus = np.array(corpus).astype('float32')
corpus = np.unique(corpus, axis=0)

# %%
corpus.shape
# Out:
# (24954, 512)

# %%
corpus
# Out:
# array([[-0.84421384,  0.16233554,  0.30725527, ...,  0.4009103 ,
#         -0.20468222, -0.11151451],
#        [-0.82529694,  0.26502076,  0.05470029, ...,  0.27426323,
#         -0.56668675, -0.08001336],
#        [-0.8063227 , -0.1909807 , -0.2237772 , ...,  0.25489452,
#         -0.12389579,  0.2758569 ],
#        ...,
#        [ 0.9416138 ,  0.25078082,  0.20232335, ...,  0.359342  ,
#         -0.11814606, -0.41626814],
#        [ 0.95560956,  0.44172806,  0.06752466, ...,  0.00269201,
#          0.08827078, -0.36235633],
#        [ 1.0331681 ,  0.42330468, -0.11260845, ...,  0.16301972,
#          0.00906926, -0.25052622]], dtype=float32)

# %%
dimension = corpus.shape[-1]
dimension
# Out:
# 512

# %%
model_name = 'sentence-transformers/clip-ViT-B-32'

# %%
model = SentenceTransformer(model_name)

# %%
ELASTIC_HOST="localhost"
ELASTIC_INDEX="unsplash"
ELASTIC_PORT=9200

ELASTIC_FULL_URL =f"http://{ELASTIC_HOST}:{ELASTIC_PORT}"

# %%
client = Elasticsearch(
    [ELASTIC_FULL_URL]
)

# %%
# ?client.indices.create
# Out:
# Signature:
# client.indices.create(
#     *,
#     index: str,
#     aliases: Union[Mapping[str, Mapping[str, Any]], NoneType] = None,
#     error_trace: Union[bool, NoneType] = None,
#     filter_path: Union[str, List[str], Tuple[str, ...], NoneType] = None,
#     human: Union[bool, NoneType] = None,
#     mappings: Union[Mapping[str, Any], NoneType] = None,
#     master_timeout: Union[ForwardRef('t.Literal[-1]'), ForwardRef('t.Literal[0]'), str, NoneType] = None,
#     pretty: Union[bool, NoneType] = None,
#     settings: Union[Mapping[str, Any], NoneType] = None,
#     timeout: Union[ForwardRef('t.Literal[-1]'), ForwardRef('t.Literal[0]'), str, NoneType] = None,
#     wait_for_active_shards: Union[int, ForwardRef("t.Literal['all', 'index-setting']"), str, NoneType] = None,
# ) -> elastic_transport.ObjectApiResponse[typing.Any]
# Docstring:
# Creates an index with optional settings and mappings.
#
# `<https://www.elastic.co/guide/en/elasticsearch/reference/8.7/indices-create-index.html>`_
#
# :param index: The name of the index
# :param aliases:
# :param mappings: Mapping for fields in the index. If specified, this mapping
#     can include: - Field names - Field data types - Mapping parameters
# :param master_timeout: Specify timeout for connection to master
# :param settings:
# :param timeout: Explicit operation timeout
# :param wait_for_active_shards: Set the number of active shards to wait for before
#     the operation returns.
# File:      /opt/conda/lib/python3.7/site-packages/elasticsearch/_sync/client/indices.py
# Type:      method

# %%
def create_index_brute(client,index:str, num_shards=3):
    """Creates an index in Elasticsearch. Delete old index."""
    
    if client.indices.exists(index=index):
        client.indices.delete(index=index)
    
    client.indices.create(
        index=index
        ,settings = {"number_of_shards": num_shards}
        ,mappings= {
            
            "properties": {
                        "embeddings": { "type": "dense_vector","dims": 512 , "index":False }
                        ,"description_final": {"type": "text"}
                   }
            }

    )
    
def create_index_knn(client,index:str, num_shards=3):
    """Creates an index in Elasticsearch. Delete old index."""
    
    if client.indices.exists(index=index):
        client.indices.delete(index=index)
    
    client.indices.create(
        index=index
        ,settings = {"number_of_shards": num_shards}
        ,mappings= {
            
            "properties": {
                        "embeddings": { "type": "dense_vector","dims": 512 , "index": True, "similarity":"cosine" }
                        ,"description_final": {"type": "text"}
                   }
            }

    )


def generate_docs(df:pd.DataFrame):
    """
    Given a datframe containing posts data, yields a generator of dicitionary 
    """
    
    # iterate over dataframe contains posts with metadata
    df = df[['photo_id','description_final','photo_image_url' ,'embeddings']]
    for index, row in df.iterrows():
        doc = {**row} 
        
        # use PostId as document id
        doc['_id'] = doc["photo_id"]
        
        yield doc

# %%
create_index_brute(client, index= ELASTIC_INDEX, num_shards=1)

# %%
df_subset = dset.to_pandas()

# %%
df_subset.head()
# Out:
#       photo_id                                photo_url  \
# 0  XMyPniM9LF0  https://unsplash.com/photos/XMyPniM9LF0
# 1  rDLBArZUl1c  https://unsplash.com/photos/rDLBArZUl1c
# 2  cNDGZ2sQ3Bo  https://unsplash.com/photos/cNDGZ2sQ3Bo
# 3  iuZ_D1eoq9k  https://unsplash.com/photos/iuZ_D1eoq9k
# 4  BeD3vjQ8SI0  https://unsplash.com/photos/BeD3vjQ8SI0
#
#                                      photo_image_url  \
# 0  https://images.unsplash.com/uploads/1411949294...
# 1  https://images.unsplash.com/photo-141633941111...
# 2  https://images.unsplash.com/photo-142014251503...
# 3  https://images.unsplash.com/photo-141487280988...
# 4  https://images.unsplash.com/photo-141700759404...
#
#            photo_submitted_at photo_featured  photo_width  photo_height  \
# 0  2014-09-29 00:08:38.594364              t         4272          2848
# 1   2014-11-18 19:36:57.08945              t         3000          4000
# 2  2015-01-01 20:02:02.097036              t         2564          1710
# 3  2014-11-01 20:15:13.410073              t         2912          4368
# 4  2014-11-26 13:13:50.134383              t         4896          3264
#
#    photo_aspect_ratio           photo_description photographer_username  ...  \
# 0                1.50    Woman exploring a forest     michellespencer77  ...
# 1                0.75   Succulents in a terrarium                ugmonk  ...
# 2                1.50   Rural winter mountainside             johnprice  ...
# 3                0.67     Poppy seeds and flowers            krisatomic  ...
# 4                1.50  Silhouette near dark trees         jonaseriksson  ...
#
#   stats_downloads                                     ai_description  \
# 0            6967              woman walking in the middle of forest
# 1           82141          succulent plants in clear glass terrarium
# 2            3428           rocky mountain under gray sky at daytime
# 3           33704  red common poppy flower selective focus phography
# 4           49662                            trees during night time
#
#   ai_primary_landmark_name ai_primary_landmark_latitude  \
# 0                     None                          NaN
# 1                     None                          NaN
# 2                     None                          NaN
# 3                     None                          NaN
# 4                     None                          NaN
#
#    ai_primary_landmark_longitude ai_primary_landmark_confidence  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#                       blur_hash           description_final  \
# 0  L56bVcRRIWMh.gVunlS4SMbsRRxr    Woman exploring a forest
# 1  LvI$4txu%2s:_4t6WUj]xat7RPoe   Succulents in a terrarium
# 2  LhMj%NxvM{t7_4t7aeoM%2M{ozj[   Rural winter mountainside
# 3  LSC7DirZAsX7}Br@GEWWmnoLWCnj     Poppy seeds and flowers
# 4  L25|_:V@0hxtI=W;odae0ht6=^NG  Silhouette near dark trees
#
#                                                image  \
# 0  {'bytes': None, 'path': '../data/raw/images/XM...
# 1  {'bytes': None, 'path': '../data/raw/images/rD...
# 2  {'bytes': None, 'path': '../data/raw/images/cN...
# 3  {'bytes': None, 'path': '../data/raw/images/iu...
# 4  {'bytes': None, 'path': '../data/raw/images/Be...
#
#                                           embeddings
# 0  [-0.23112005, 0.67399395, 0.16962554, 0.137191...
# 1  [-0.45541775, 0.42470074, -0.09068765, 0.14057...
# 2  [-0.25890213, 0.642249, 0.095262825, 0.1934405...
# 3  [0.024865545, 0.15010555, -0.21668568, -0.3788...
# 4  [-0.4102839, 0.0026709028, 0.07259746, 0.11741...
#
# [5 rows x 34 columns]

# %%
number_of_docs = len(df_subset)

# %%
with tqdm.auto.tqdm(total=number_of_docs , unit="docs" ) as pbar:
    successes = 0


    for ok, action in streaming_bulk(
            client=client, index=ELASTIC_INDEX, actions=generate_docs(df_subset) ,
        ):
        pbar.update(1)
        successes += ok
# Out:
#   0%|          | 0/24992 [00:00<?, ?docs/s]

# %%
rich.print (
    requests.get(f"{ELASTIC_FULL_URL}/{ELASTIC_INDEX}/_mapping").json()
    
)
# Out:
# {
#     'unsplash': {
#         'mappings': {
#             'properties': {
#                 'description_final': {'type': 'text'},
#                 'embeddings': {'type': 'dense_vector', 'dims': 512},
#                 'photo_id': {'type': 'text', 'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#                 'photo_image_url': {
#                     'type': 'text',
#                     'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}
#                 }
#             }
#         }
#     }
# }

# %%
def fetch_results(client:Elasticsearch, query:str,  num_hits=5, fields = ["description_final"], explain=False, use_brute_force=True):
    """
    With the passed elastic search client, return documents that contain the passed `query` in the fields specified by `fields`

    If the fields is empty, it will search all text fields
    
    We are using mult-match, which by default uses `or`
    https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-match-query.html
    """

    print (query)
    query_vector = model.encode(query).tolist()

    
    payload_knn = None
    payload_brute_force = None
    
    if not use_brute_force:
        payload_knn = {
                "field": "embeddings",
                "query_vector": query_vector,
                "k": 10,
                "num_candidates": 100
        }
    else:
        payload_brute_force = {
            "script_score": {
                      "query": { "match_all": {} },

                      "script": {
                        "source": "cosineSimilarity(params.query_vector, 'embeddings') + 1.0", 
                        "params": {
                          "query_vector": query_vector
                        },

                      }
                    }
        }
    

    
    resp = client.search(
        query= payload_brute_force
        , knn=payload_knn
        , fields=fields
        ,size = num_hits
    )
    
    return resp

def find_results(query:str , k =5, explain=False, use_brute_force=True):
    
    time_start=time.time_ns()
    top_items = fetch_results(client,query=query,num_hits=k, use_brute_force=use_brute_force)
    time_end=time.time_ns()
    
    elapsed_time_ms = (time_end - time_start) // 1_000_000
    

    display(HTML(f"<h3>Query: {query} </h3>"))
    

    images = []
    labels = []
    
    # Iterate over the top k results
    for hit in top_items['hits']['hits']:
        doc_id = hit['_id']
        
        photo_data = hit["_source"]
        
        # Display the photo
        
        images.append(photo_data["photo_image_url"])
        score = "{:.2f}".format(hit['_score'])
        
        labels.append (f"""
                     Photo title: {photo_data["description_final"]}   <br/>
                     Distance: {score}
            
                     """)
    
        
    ipyplot.plot_images(images=images, labels=labels, img_width=200)
        
        
    if explain:
        return JSON (top_items.body , expanded=False)
    
    print(f"Elapsed tims(ms): {elapsed_time_ms} ")

# %%
find_results("boy playing in the beach", use_brute_force=True)
# Out:
# boy playing in the beach
# <h3>Query: boy playing in the beach </h3>
#     <style>
#         #ipyplot-html-viewer-toggle-TZ9HeWaqZ3wHtNrs4JXRX6 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-TZ9HeWaqZ3wHtNrs4JXRX6 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-TZ9HeWaqZ3wHtNrs4JXRX6 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-TZ9HeWaqZ3wHtNrs4JXRX6:checked ~ #ipyplot-html-viewer-textarea-TZ9HeWaqZ3wHtNrs4JXRX6 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-TZ9HeWaqZ3wHtNrs4JXRX6:checked + #ipyplot-html-viewer-label-TZ9HeWaqZ3wHtNrs4JXRX6:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-TZ9HeWaqZ3wHtNrs4JXRX6">
#         <label id="ipyplot-html-viewer-label-TZ9HeWaqZ3wHtNrs4JXRX6" for="ipyplot-html-viewer-toggle-TZ9HeWaqZ3wHtNrs4JXRX6">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-TZ9HeWaqZ3wHtNrs4JXRX6" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-hG3gLBSoCKr8cpmvM2F5FN {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-hG3gLBSoCKr8cpmvM2F5FN {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-hG3gLBSoCKr8cpmvM2F5FN">
#     <div class="ipyplot-placeholder-div-hG3gLBSoCKr8cpmvM2F5FN">
#         <div id="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-UEPCzsKEKyjUAxH7BAmNGW" class="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: boy jumping near stack of stones on seashore during golden hour   <br/>
#                      Distance: 1.30
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1579279238256-a763f3b91d32</h4><img src="https://images.unsplash.com/photo-1579279238256-a763f3b91d32"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-UEPCzsKEKyjUAxH7BAmNGW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-hG3gLBSoCKr8cpmvM2F5FN">
#         <div id="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-5R45aLy78FxaQFMQVo9GHP" class="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: boy in wetsuit jumping on shore   <br/>
#                      Distance: 1.30
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1426377086393-b299c381364a</h4><img src="https://images.unsplash.com/photo-1426377086393-b299c381364a"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-5R45aLy78FxaQFMQVo9GHP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-hG3gLBSoCKr8cpmvM2F5FN">
#         <div id="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-P7P5eNMP9i3MXvuNQnWBxE" class="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: boy playing on shore under blue sky during daytime   <br/>
#                      Distance: 1.29
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1426377070741-3a6a3dcfd01c</h4><img src="https://images.unsplash.com/photo-1426377070741-3a6a3dcfd01c"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-P7P5eNMP9i3MXvuNQnWBxE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-hG3gLBSoCKr8cpmvM2F5FN">
#         <div id="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-VTuLrTGroD8HKjGaQ4EGwA" class="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: Surf Town   <br/>
#                      Distance: 1.29
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1489556093415-4148d7f8de93</h4><img src="https://images.unsplash.com/photo-1489556093415-4148d7f8de93"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-VTuLrTGroD8HKjGaQ4EGwA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-hG3gLBSoCKr8cpmvM2F5FN">
#         <div id="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-LtSfXMjPTUUMbGnnsB2HJv" class="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: baby sittin on sand   <br/>
#                      Distance: 1.29
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left:
#         <style>
#         #ipyplot-imgs-container-div-hG3gLBSoCKr8cpmvM2F5FN {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-hG3gLBSoCKr8cpmvM2F5FN {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-hG3gLBSoCKr8cpmvM2F5FN">
#     <div class="ipyplot-placeholder-div-hG3gLBSoCKr8cpmvM2F5FN">
#         <div id="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-UEPCzsKEKyjUAxH7BAmNGW" class="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: boy jumping near stack of stones on seashore during golden hour   <br/>
#                      Distance: 1.30
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1579279238256-a763f3b91d32</h4><img src="https://images.unsplash.com/photo-1579279238256-a763f3b91d32"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-UEPCzsKEKyjUAxH7BAmNGW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-hG3gLBSoCKr8cpmvM2F5FN">
#         <div id="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-5R45aLy78FxaQFMQVo9GHP" class="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: boy in wetsuit jumping on shore   <br/>
#                      Distance: 1.30
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1426377086393-b299c381364a</h4><img src="https://images.unsplash.com/photo-1426377086393-b299c381364a"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-5R45aLy78FxaQFMQVo9GHP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-hG3gLBSoCKr8cpmvM2F5FN">
#         <div id="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-P7P5eNMP9i3MXvuNQnWBxE" class="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: boy playing on shore under blue sky during daytime   <br/>
#                      Distance: 1.29
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1426377070741-3a6a3dcfd01c</h4><img src="https://images.unsplash.com/photo-1426377070741-3a6a3dcfd01c"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-P7P5eNMP9i3MXvuNQnWBxE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-hG3gLBSoCKr8cpmvM2F5FN">
#         <div id="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-VTuLrTGroD8HKjGaQ4EGwA" class="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: Surf Town   <br/>
#                      Distance: 1.29
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1489556093415-4148d7f8de93</h4><img src="https://images.unsplash.com/photo-1489556093415-4148d7f8de93"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-VTuLrTGroD8HKjGaQ4EGwA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-hG3gLBSoCKr8cpmvM2F5FN">
#         <div id="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-LtSfXMjPTUUMbGnnsB2HJv" class="ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: baby sittin on sand   <br/>
#                      Distance: 1.29
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1542178805-14a89821bb25</h4><img src="https://images.unsplash.com/photo-1542178805-14a89821bb25"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hG3gLBSoCKr8cpmvM2F5FN-LtSfXMjPTUUMbGnnsB2HJv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# Elapsed tims(ms): 56

# %%
create_index_knn(client, index= ELASTIC_INDEX, num_shards=1)

# %%
with tqdm.auto.tqdm(total=number_of_docs , unit="docs" ) as pbar:
    successes = 0


    for ok, action in streaming_bulk(
            client=client, index=ELASTIC_INDEX, actions=generate_docs(df_subset) ,
        ):
        pbar.update(1)
        successes += ok
# Out:
#   0%|          | 0/24992 [00:00<?, ?docs/s]

# %%
rich.print (
    requests.get(f"{ELASTIC_FULL_URL}/{ELASTIC_INDEX}/_mapping").json()
    
)
# Out:
# {
#     'unsplash': {
#         'mappings': {
#             'properties': {
#                 'description_final': {'type': 'text'},
#                 'embeddings': {'type': 'dense_vector', 'dims': 512, 'index': True, 'similarity': 'cosine'},
#                 'photo_id': {'type': 'text', 'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#                 'photo_image_url': {
#                     'type': 'text',
#                     'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}
#                 }
#             }
#         }
#     }
# }

# %%
find_results("boy playing in the beach", use_brute_force=False)
# Out:
# boy playing in the beach
# <h3>Query: boy playing in the beach </h3>
#     <style>
#         #ipyplot-html-viewer-toggle-Sxqonr8V58ZJZDLep5tnkA {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Sxqonr8V58ZJZDLep5tnkA {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Sxqonr8V58ZJZDLep5tnkA {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Sxqonr8V58ZJZDLep5tnkA:checked ~ #ipyplot-html-viewer-textarea-Sxqonr8V58ZJZDLep5tnkA {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Sxqonr8V58ZJZDLep5tnkA:checked + #ipyplot-html-viewer-label-Sxqonr8V58ZJZDLep5tnkA:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-Sxqonr8V58ZJZDLep5tnkA">
#         <label id="ipyplot-html-viewer-label-Sxqonr8V58ZJZDLep5tnkA" for="ipyplot-html-viewer-toggle-Sxqonr8V58ZJZDLep5tnkA">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-Sxqonr8V58ZJZDLep5tnkA" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-Yf96mUkqLsfDGqiDArrTiv {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Yf96mUkqLsfDGqiDArrTiv {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Yf96mUkqLsfDGqiDArrTiv">
#     <div class="ipyplot-placeholder-div-Yf96mUkqLsfDGqiDArrTiv">
#         <div id="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-HzyfzL2TDSixk4gPzoTQkF" class="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: boy jumping near stack of stones on seashore during golden hour   <br/>
#                      Distance: 0.65
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1579279238256-a763f3b91d32</h4><img src="https://images.unsplash.com/photo-1579279238256-a763f3b91d32"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-HzyfzL2TDSixk4gPzoTQkF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Yf96mUkqLsfDGqiDArrTiv">
#         <div id="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-Y6pGb4KCMgq4FkPmHjW3Hk" class="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: boy in wetsuit jumping on shore   <br/>
#                      Distance: 0.65
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1426377086393-b299c381364a</h4><img src="https://images.unsplash.com/photo-1426377086393-b299c381364a"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-Y6pGb4KCMgq4FkPmHjW3Hk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Yf96mUkqLsfDGqiDArrTiv">
#         <div id="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-Y5nyHNLWiwbiL2C3xxURTm" class="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: boy playing on shore under blue sky during daytime   <br/>
#                      Distance: 0.65
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1426377070741-3a6a3dcfd01c</h4><img src="https://images.unsplash.com/photo-1426377070741-3a6a3dcfd01c"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-Y5nyHNLWiwbiL2C3xxURTm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Yf96mUkqLsfDGqiDArrTiv">
#         <div id="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-nUg4d3WYo59uZfiRU7aBWf" class="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: Surf Town   <br/>
#                      Distance: 0.65
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1489556093415-4148d7f8de93</h4><img src="https://images.unsplash.com/photo-1489556093415-4148d7f8de93"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-nUg4d3WYo59uZfiRU7aBWf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Yf96mUkqLsfDGqiDArrTiv">
#         <div id="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-WS2W5C6TC9hrDB88LoqnXN" class="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: baby sittin on sand   <br/>
#                      Distance: 0.65
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left:
#         <style>
#         #ipyplot-imgs-container-div-Yf96mUkqLsfDGqiDArrTiv {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Yf96mUkqLsfDGqiDArrTiv {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Yf96mUkqLsfDGqiDArrTiv">
#     <div class="ipyplot-placeholder-div-Yf96mUkqLsfDGqiDArrTiv">
#         <div id="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-HzyfzL2TDSixk4gPzoTQkF" class="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: boy jumping near stack of stones on seashore during golden hour   <br/>
#                      Distance: 0.65
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1579279238256-a763f3b91d32</h4><img src="https://images.unsplash.com/photo-1579279238256-a763f3b91d32"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-HzyfzL2TDSixk4gPzoTQkF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Yf96mUkqLsfDGqiDArrTiv">
#         <div id="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-Y6pGb4KCMgq4FkPmHjW3Hk" class="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: boy in wetsuit jumping on shore   <br/>
#                      Distance: 0.65
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1426377086393-b299c381364a</h4><img src="https://images.unsplash.com/photo-1426377086393-b299c381364a"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-Y6pGb4KCMgq4FkPmHjW3Hk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Yf96mUkqLsfDGqiDArrTiv">
#         <div id="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-Y5nyHNLWiwbiL2C3xxURTm" class="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: boy playing on shore under blue sky during daytime   <br/>
#                      Distance: 0.65
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1426377070741-3a6a3dcfd01c</h4><img src="https://images.unsplash.com/photo-1426377070741-3a6a3dcfd01c"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-Y5nyHNLWiwbiL2C3xxURTm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Yf96mUkqLsfDGqiDArrTiv">
#         <div id="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-nUg4d3WYo59uZfiRU7aBWf" class="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: Surf Town   <br/>
#                      Distance: 0.65
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1489556093415-4148d7f8de93</h4><img src="https://images.unsplash.com/photo-1489556093415-4148d7f8de93"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-nUg4d3WYo59uZfiRU7aBWf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Yf96mUkqLsfDGqiDArrTiv">
#         <div id="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-WS2W5C6TC9hrDB88LoqnXN" class="ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
#                      Photo title: baby sittin on sand   <br/>
#                      Distance: 0.65
#
#                      </h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://images.unsplash.com/photo-1542178805-14a89821bb25</h4><img src="https://images.unsplash.com/photo-1542178805-14a89821bb25"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Yf96mUkqLsfDGqiDArrTiv-WS2W5C6TC9hrDB88LoqnXN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# Elapsed tims(ms): 36

# %% [markdown]
# ## Create the <a href ="https://github.com/facebookresearch/faiss">FAISS</a> index.
# <br/>FAISS will be used to create the vector search space using the embeddings corpus.
# <br/>We are going to use FlatIndex to store the index, but <a href="https://github.com/facebookresearch/faiss/wiki/Faiss-indexes">other efficient indexes</a> are also available in FAISS.
# <br/> FAISS supports both GPU and CPU based index. GPU index search is <a href="https://github.com/facebookresearch/faiss/wiki/Comparing-GPU-vs-CPU">comparatively faster </a> compared to CPU as long as complete index could fit in memory.

# %% [markdown]
# ### Flat Index

# %%
xb = corpus
xb.shape
dimension = xb.shape[-1]
#initialize the flat index for data dimension. In current example it is 512
index = faiss.IndexFlatL2(dimension)

# %%
index.is_trained

# %%
# add data to the index. This is a CPU based index.
index.add(xb)

# %%
xq = xb

# %%
len(xq)

# %% [markdown]
# number of vectors / results to retrieve

# %%
k =1

# %% [markdown]
# #### Index Search
# search method returns query indices (I) similar to search query vector and their euclidean distances (D) from the search query vector.

# %% [markdown]
# search for single vector

# %%
# %%timeit
D, I = index.search(xq[:1], k)

# %% [markdown]
# search for all vectors in corpus

# %%
# %%time
D, I = index.search(xq, k)

# %% [markdown]
# distance of vector in corpus to query vector

# %%
D

# %% [markdown]
# top vertex id

# %%
I

# %% [markdown]
# because we are using the entire corpus and the ids are sequential, the ideal recall would be sequential too

# %%
z = I[:,0] == np.array( list(range(len(xq))))
z

# %%
{
 "recall@1":  z.sum()
 , "num_vectors":  len(z)
 , "mismatch":    len(z) - z.sum()
}

# %%
np.array( list(range(len(xq))))[z]

# %%
z

# %%
np.where(z == False)

# %%
D[3766]

# %%
I[3766]

# %% [markdown]
# ### faiss ivf

# %% [markdown]
# <img src="https://d33wubrfki0l68.cloudfront.net/44acb1425f25e30ca058daec92bdb209c6c47ad2/e92fc/images/faiss5.png" width="500"/>
#
# <p> Image from Pinecone Faiss Tutorial </p>
# https://www.pinecone.io/learn/faiss-tutorial/
#
#
# **Parameters**:
# - nlist : number of clusters
# - nprobe: number of clusters to search

# %%
nlist = 20 # number of clusters
quantizer = faiss.IndexFlatL2(dimension)  # the other index
index = faiss.IndexIVFFlat(quantizer, dimension, nlist, faiss.METRIC_L2)

# %%
assert not index.is_trained
index.train(xb)
assert index.is_trained

# %%
xq = xb
# create another index for IVFFlat
index.add(xb)

# %% [markdown]
# search for single vector

# %%
# %%timeit


index.nprobe = 1              # default nprobe is 1

D, I = index.search(xq[:1], k)     # actual search

# %% [markdown]
# search for entire corpus

# %%
# %%time


index.nprobe = 1              

D, I = index.search(xq, k)     # actual search

# %%
z = I[:,0] == np.array( list(range(len(xq))))
{
 "recall@1":  z.sum()
 , "num_vectors":  len(z)
 , "mismatch":    len(z) - z.sum()
}

# %% [markdown]
# increase the number of cells that are probed

# %%
# %%time
index.nprobe = 5              # default nprobe is 1

D, I = index.search(xq, k)

# %%
z = I[:,0] == np.array( list(range(len(xq))))
{
 "recall@1":  z.sum()
 , "num_vectors":  len(z)
 , "mismatch":    len(z) - z.sum()
}
